# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from medical_data_visualizer import draw_cat_plot, draw_heat_map
# Draw categorical plot
fig1 = draw_cat_plot()
plt.show()  # displays inline in Jupyter

# Draw heatmap
fig2 = draw_heat_map()
plt.show()
fig1.savefig('catplot_jupyter.png')
fig2.savefig('heatmap_jupyter.png')
